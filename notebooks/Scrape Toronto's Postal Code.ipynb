# %% [markdown]
# # Scrape Toronto's Postal Code from Wikipedia

# %% [markdown]
# ## Section 1 - Scraping

# %% [markdown]
# ### 1. Import all the needed resources, as well as initializing the Wikipedia URL that we want to scrape

# %%
import requests
import lxml.html as lh
import pandas as pd

wikipedia_url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# ### 2. Extract the HTML content from the URL, parse it into HTML document and get the table using XPath

# %%
response = requests.get(wikipedia_url)

doc = lh.fromstring(response.content)
table = doc.xpath('//table[@class=\'wikitable sortable\']')

# %% [markdown]
# ### 3. Convert the table into Panda DataFrame
#
# Note that there is no specific ID defined in the HTML table in Wikipedia page, and therefore, a little bit of hack is needed.
# The loop will stop if the iterator finds the first element of the table is empty, which is indicating that it is now going through the next table which we don't need

# %%
rows = table[0].xpath('//tr')
colums = []
toronto_df = None

for i, r in enumerate(rows):
    data_row = [r[0].text_content().rstrip(),
                r[1].text_content().rstrip() if r[1].text_content().rstrip() != 'Not assigned' else None,
                r[2].text_content().rstrip() if r[2].text_content().rstrip() != 'Not assigned' else None]
    if i == 0:
        columns = data_row
        toronto_df = pd.DataFrame(columns=columns)
    else:
        if r[0].text_content().rstrip() == '':
            break
        tmp = pd.DataFrame([data_row], columns=columns)
        toronto_df = toronto_df.append(tmp, ignore_index=True)

toronto_df
# Out:
#     Postal Code           Borough  \
# 0           M1A              None
# 1           M2A              None
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z              None
# 176         M6Z              None
# 177         M7Z              None
# 178         M8Z         Etobicoke
# 179         M9Z              None
#
#                                          Neighbourhood
# 0                                                 None
# 1                                                 None
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                               None
# 176                                               None
# 177                                               None
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                               None
#
# [180 rows x 3 columns]

# %% [markdown]
# ## Section 2 - Geocoder

# %% [markdown]
# ### 1. Download the Geospatial data and load it to DataFrame

# %%
# !wget -O geospatial_data.csv https://cocl.us/Geospatial_data
# Out:
# --2020-12-24 11:01:59--  https://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.63.96.194, 169.63.96.176
# Connecting to cocl.us (cocl.us)|169.63.96.194|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-12-24 11:02:00--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 185.235.236.197
# Connecting to ibm.box.com (ibm.box.com)|185.235.236.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-12-24 11:02:00--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-12-24 11:02:00--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 185.235.236.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|185.235.236.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!nw21C-zVMYJeQ2BGg1PK2Rjeg0HztSBAY5R9TOCeGTzXsj3uAaoo_0GW_xjYl08JnuCXAczHkWyqMa6z60jYMy3y1qDQtKvOynVFfXP7B-CGCUTr3LFkfQ5GXx82Y9C9zFVauWU721f9ISDOo_4f6ZDSj78xh7WO_F55npkrAj94oxSIjK7JVlf0WI8Y0R-iTnYy8gcDwpiId9ALIBYQ_j0w42TWet6giokeiQ-qLGPAgRhZ933GSgVzJ_STf3iVWQj1WXyY7BgpgI6oEQuyryc9reOT9_X5ploGpauuPFh97FAZvkvc2iwJgZdzbuivPN5z9Ds3pHH8rjEElxunwv-aHkvx_MaR9QnBz3n3TMpTeZs1Ut7hxFxpWms-ahrm7iVkXIB1wBmhUGArFJxca5zvqRlSwVgzO2TMet6svT1vI0Y_TF2j3NglL9apRbeW_EbT
WWU_xfd35beFf-9MeK9yzsnY6kJ4VJ64qYHzdRzsbKvSWOoMtNdWWPHvvo06GnC7m0Qbs1NxgtTryztKqMDwNJh2RJ956y0nySPYE8Kv2y9z1MnbGeisOwAjq-D78VC3Md3pz83XeMVEC1TRjrJRpf9Z9hGyITHVFOP6o39nYzoCRcZSst2d4dyL_NCTZakBA2d93VZkEkONaUT5pEGGPs4mnUgUzxpmRMM0TWhNgYjqEglNVC1TaUMwq2JPsr6sESmqGuX33qO6XeCN2Eoe6PnTGtXcIs7ic7F2rglkHsRGE66Mw6-BfZdxM7R0JM88JpYoCUqlWdC0Rns433od6as27oG2lGRLwSjhjl68k52jZJNawDYTewwCLDpSes453c3Cj-WRHba4FNdLQR2Yo3vhGjzIZH1JNclTUFVWrWiFfOU1-Rjifw2IjR2ikMfLmsHkBfTQ26czWLxmVTkrSrwJOaqMXS6WKmBfgLvu9n63sns52slDYpOUOZGYcdKoVBcdaM_UDEaUbHWBX1fX41yeg2GUy9hQiNu4ePKpuSjiGmPpEL15-0HF4NwA2SKwdnaIa_MFlgiFgSKH4huptSGmXHvtAdtQzFzGd2WpjR4o1ZtFI6FtKqGck3Okx_bnMgzchsSdRggEECryteib0A-oPKbdEEWKA5In8aUDBa9Db3PtedO78g04G2gXQbQQEI-_zNQe9ohCF0n-Mc39xVr2IDC6kjk5tsXA4RuJhzC57fGY5XySDvf5mZ59xj4Nva2-DgB4YFZAwbeTNW9e5NzAXfrtNhCNyjTj2amB1AZHLPHLQKueB-PJDc3dy2v8GTMrUU4dJnBJnJnsWFt82ayBMcfaZA2b6AH40jsgbW1PEC7O5A7c_8yQ_fypAobnPfJ6V1LJrYf8RaVLfGk8hga-eHP9aiCw7oXVAJ7lQOGtjWm9lUX1vR6DCHg0goRlgF_4PD-sZKdXLFXpoRkZEPwGF_SxJE1bQpBq1_SmqfCbpSkmVQoiH46L3a9sORgN4io8p-pW76QQ../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.29.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.29.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘geospatial_data.csv’
#
# geospatial_data.csv 100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2020-12-24 11:02:02 (53.2 MB/s) - ‘geospatial_data.csv’ saved [2891/2891]

# %%
toronto_geo_df = pd.read_csv('geospatial_data.csv')
toronto_geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### 2. Cross reference the Geospatial data with postal code data, as well as perform data clean-up

# %%
complete_toronto_df = toronto_df.copy()
complete_toronto_df = complete_toronto_df.join(toronto_geo_df.set_index('Postal Code'), on='Postal Code', how='left')
complete_toronto_df = complete_toronto_df.dropna(subset=['Latitude'])
complete_toronto_df = complete_toronto_df[complete_toronto_df['Neighbourhood'] != None]
complete_toronto_df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 2                                            Parkwoods  43.753259 -79.329656
# 3                                     Victoria Village  43.725882 -79.315572
# 4                            Regent Park, Harbourfront  43.654260 -79.360636
# 5                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 6          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 160      The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 165                               Church and Wellesley  43.665860 -79.383160
# 168  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 178  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# ## Section 3 - Segmenting and Clustering

# %%
# !conda install -c conda-forge geopy --yes
# !conda install -c conda-forge folium=0.5.0 --yes

print('Folium and Geopy are installed')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: |
